# %%
def oddNumbers(l, r):
    # Write your code here
    for i in range(l,r+1):
        if i%2==0:
            pass
        else:
            print(i)
oddNumbers(2,9)
# Out:
# 3
# 5
# 7
# 9

# %%
if __name__ == '__main__':
    n = int(input())
    sq=0
    for i in range(n):
      print(i*i)
# Out:
# 5
# 0
# 1
# 4
# 9
# 16

# %% [markdown]
# # New Section

# %%
for characters in "analytics":
  if (characters=='a') or (characters=='i'):
    print('x', end=' ')
  else :
    print(characters, end=' ')
# Out:
# x n x l y t x c s

# %%
number=10
while number>5:
  print(number, end=' ')
  number = number-1
  if number==8:
    number=2
# Out:
# 10 9
