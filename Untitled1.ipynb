# %%
string = list(map(str, input().lower()))
lst = []
for i in range(0, len(string)):
  if string[i]=='a' or string[i]=='e' or string[i]=='i' or string[i]=='o' or string[i]=='u':
    lst.append(string[i])
x = len(lst)
y = len(string)
print(x, y)
print(y-x)
# Out:
# aaabvbcioinoio
# 9 14
# 5

# %%
n = input("Enter the word and see if it is palindrome: ") #check palindrome
print(n[::-1])
if n == n[::-1]:
    print("This word is palindrome")
else:
    print("This word is not palindrome")
# Out:
# Enter the word and see if it is palindrome: bhbdh
# hdbhb
# This word is not palindrome

# %%
def isPalindrome(s):
    return s == s[::-1]
 
# strr = str(input())
strr = "abab"

lst = []

for i in range(len(strr)):
  for j in range(i+1):
    s = strr[j]
    print(s, end  = ' ')
    continue
  print()



# s = "malyalamm"
# ans = isPalindrome(s)
 
# if ans:
#     print("Yes")
# else:
#     print("No")
# Out:
# a
# a b
# a b a
# a b a b

# %%
class Solution:
    def kClosest(self, points: List[List[int]], k: int) -> List[List[int]]:
        pass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-929ac31a4dfd> in <module>()
# ----> 1 class Solution:
#       2     def kClosest(self, points: List[List[int]], k: int) -> List[List[int]]:
#       3         pass
#
# <ipython-input-62-929ac31a4dfd> in Solution()
#       1 class Solution:
# ----> 2     def kClosest(self, points: List[List[int]], k: int) -> List[List[int]]:
#       3         pass
#
# NameError: name 'List' is not defined

# %%
# A Python3 solution for longest palindrome

# Function to pra subString str[low..high]
def printSubStr(str, low, high):
	
	for i in range(low, high + 1):
		print(str[i], end = "")

# This function prints the
# longest palindrome subString
# It also returns the length
# of the longest palindrome
def longestPalSubstr(str):
	
	# Get length of input String
	n = len(str)
	
	# All subStrings of length 1
	# are palindromes
	maxLength = 1
	start = 0
	
	# Nested loop to mark start
	# and end index
	for i in range(n):
		for j in range(i, n):
			flag = 1
			
			# Check palindrome
			for k in range(0, ((j - i) // 2) + 1):
				if (str[i + k] != str[j - k]):
					flag = 0

			# # Palindrome
			if (flag != 0 and (j - i + 1) > maxLength):
				start = i
				maxLength = j - i + 1
				
	# print("Longest palindrome subString is: ", end = "")
	printSubStr(str, start, start + maxLength - 1)
	# Return length of LPS
	return maxLength

# Driver Code
if __name__ == '__main__':

	str = "forgeeksskeegfor"
	
	print(longestPalSubstr(str), end = ' ')

# This code is contributed by 29AjayKumar
# Out:
# geeksskeeg10

# %%
buildingCount = [2,1,1,3]
routerLocation = [1,2]
routerRange = [2,0]


def gSerBuild(buildingCount, routerLocation, routerRange):
  count = 0
  # x = len(routerLocation)
  for i in range(len(routerLocation)):
    x  = routerLocation[i]
    for j in range(len(routerRange)):
      y = routerRange[j]
      range = [i]
    print(x)

print(gSerBuild(buildingCount, routerLocation, routerRange))
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-2-7d7ab2636de5> in <module>()
#      14     print(x)
#      15
# ---> 16 print(gSerBuild(buildingCount, routerLocation, routerRange))
#
# <ipython-input-2-7d7ab2636de5> in gSerBuild(buildingCount, routerLocation, routerRange)
#       7   count = 0
#       8   # x = len(routerLocation)
# ----> 9   for i in range(len(routerLocation)):
#      10     x  = routerLocation[i]
#      11     for j in range(len(routerRange)):
#
# UnboundLocalError: local variable 'range' referenced before assignment

# %%
buildingCount = [2,1,1,3]
routerLocation = [1,2]
routerRange = [2,0]


x = len(buildingCount)
y = len(routerLocation)
while x > 0:
  # print(x)
  # print(buildingCount[x-1], "2")
  for i in range(y):
    print(routerLocation[i])

  x -= 1
# Out:
# 1
# 2

# %%
n = 5
x = [1,2,3,4,5,6]

for i in range(0, len(x)):
  for j in range(i+1, len(x)):
